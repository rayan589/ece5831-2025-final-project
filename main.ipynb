# %% [markdown]
# # Agentic Analytics Copilot — Execution Notebook
#
# This notebook demonstrates the full execution pipeline of the project for **ECE 5831 – Neural Networks and Pattern Recognition**.
#
# The project integrates:
# - A **Long Short-Term Memory (LSTM)** neural network for time-series modeling
# - **Fine-tuning** on a target dataset
# - An **agentic analytics system** that detects anomalies and recommends actions
#
# Each step below executes one major component of the system.

# %% [markdown]
# ## Step 1: Pretrain the LSTM Model
#
# In this step, a base LSTM model is trained on synthetic multi-site KPI data.
# The objective is to learn general temporal patterns such as trends and seasonality.
# The trained weights are saved and later reused for fine-tuning.

# %%
# Pretrain LSTM
# !python train_lstm_base.py
# Out:
# 2025-12-15 19:46:28.829010: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Pretraining data shapes: (8970, 30, 3) (8970, 3)
# /opt/anaconda3/envs/tf311/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0294 - val_loss: 0.0175
# Epoch 2/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0167 - val_loss: 0.0173
# Epoch 3/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0167 - val_loss: 0.0174
# Epoch 4/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0166 - val_loss: 0.0172
# Epoch 5/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0166 - val_loss: 0.0172
# Epoch 6/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0165 - val_loss: 0.0173
# Epoch 7/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0166 - val_loss: 0.0173
# Epoch 8/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0165 - val_loss: 0.0172
# Epoch 9/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0165 - val_loss: 0.0171
# Epoch 10/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0165 - val_loss: 0.0172
# Epoch 11/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0165 - val_loss: 0.0171
# Epoch 12/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0166 - val_loss: 0.0175
# Epoch 13/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0165 - val_loss: 0.0172
# Epoch 14/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0164 - val_loss: 0.0171
# Epoch 15/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0165 - val_loss: 0.0172
# Epoch 16/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0164 - val_loss: 0.0175
# Epoch 17/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0165 - val_loss: 0.0175
# Epoch 18/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0164 - val_loss: 0.0173
# Epoch 19/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0165 - val_loss: 0.0174
# Epoch 20/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0165 - val_loss: 0.0175
# Epoch 21/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0165 - val_loss: 0.0171
# Epoch 22/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0164 - val_loss: 0.0171
# Epoch 23/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0164 - val_loss: 0.0172
# Epoch 24/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0164 - val_loss: 0.0171
# Epoch 25/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0164 - val_loss: 0.0171
# Epoch 26/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0164 - val_loss: 0.0172
# Epoch 27/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0164 - val_loss: 0.0172
# Epoch 28/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0164 - val_loss: 0.0171
# Epoch 29/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0164 - val_loss: 0.0171
# Epoch 30/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0164 - val_loss: 0.0172
# Epoch 31/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0164 - val_loss: 0.0172
# Epoch 32/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0164 - val_loss: 0.0171
# Epoch 33/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0164 - val_loss: 0.0170
# Epoch 34/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0164 - val_loss: 0.0171
# Epoch 35/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0164 - val_loss: 0.0171
# Epoch 36/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0164 - val_loss: 0.0171
# Epoch 37/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0164 - val_loss: 0.0171
# Epoch 38/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0164 - val_loss: 0.0173
# Epoch 39/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0164 - val_loss: 0.0171
# Epoch 40/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0163 - val_loss: 0.0170
# Epoch 41/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0164 - val_loss: 0.0170
# Epoch 42/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0163 - val_loss: 0.0171
# Epoch 43/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0163 - val_loss: 0.0170
# Epoch 44/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0163 - val_loss: 0.0171
# Epoch 45/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0163 - val_loss: 0.0170
# Epoch 46/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0164 - val_loss: 0.0171
# Epoch 47/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0163 - val_loss: 0.0171
# Epoch 48/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0163 - val_loss: 0.0170
# Epoch 49/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0163 - val_loss: 0.0171
# Epoch 50/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0162 - val_loss: 0.0170
# Epoch 51/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0162 - val_loss: 0.0169
# Epoch 52/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0162 - val_loss: 0.0170
# Epoch 53/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0162 - val_loss: 0.0169
# Epoch 54/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0162 - val_loss: 0.0171
# Epoch 55/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0162 - val_loss: 0.0169
# Epoch 56/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0162 - val_loss: 0.0169
# Epoch 57/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0162 - val_loss: 0.0170
# Epoch 58/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0161 - val_loss: 0.0169
# Epoch 59/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0161 - val_loss: 0.0168
# Epoch 60/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0161 - val_loss: 0.0170
# Epoch 61/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0160 - val_loss: 0.0169
# Epoch 62/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0160 - val_loss: 0.0169
# Epoch 63/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0161 - val_loss: 0.0168
# Epoch 64/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0160 - val_loss: 0.0168
# Epoch 65/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0160 - val_loss: 0.0168
# Epoch 66/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0160 - val_loss: 0.0168
# Epoch 67/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0160 - val_loss: 0.0169
# Epoch 68/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0160 - val_loss: 0.0168
# Epoch 69/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0160 - val_loss: 0.0169
# Epoch 70/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0160 - val_loss: 0.0168
# Epoch 71/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0160 - val_loss: 0.0168
# Epoch 72/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0160 - val_loss: 0.0169
# Epoch 73/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0160 - val_loss: 0.0170
# Epoch 74/80
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0160 - val_loss: 0.0169
# Saved base LSTM weights to state/lstm_base.weights.h5
# Saved base LSTM loss curve to charts/lstm_base_loss.png

# %% [markdown]
# ## Step 2: Fine-Tune the LSTM on the Target Site
#
# The pretrained LSTM model is fine-tuned using data from a specific target site.
# This adapts the model to site-specific behavior while retaining learned global patterns.
# The fine-tuned weights are saved for inference during anomaly detection.

# %%
# Fine-tune on target site
# !python finetune_lstm_site.py
# Out:
# 2025-12-15 19:47:54.619960: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Fine-tune data shapes: (150, 30, 3) (150, 3)
# /opt/anaconda3/envs/tf311/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /opt/anaconda3/envs/tf311/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 12 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Loaded base LSTM weights for fine-tuning.
# Epoch 1/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0411 - val_loss: 0.0463
# Epoch 2/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0390 - val_loss: 0.0462
# Epoch 3/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0385 - val_loss: 0.0462
# Epoch 4/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0383 - val_loss: 0.0462
# Epoch 5/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0383 - val_loss: 0.0459
# Epoch 6/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0381 - val_loss: 0.0456
# Epoch 7/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0382 - val_loss: 0.0463
# Epoch 8/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0378 - val_loss: 0.0456
# Epoch 9/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0382 - val_loss: 0.0449
# Epoch 10/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0377 - val_loss: 0.0456
# Epoch 11/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0374 - val_loss: 0.0458
# Epoch 12/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0372 - val_loss: 0.0452
# Epoch 13/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0370 - val_loss: 0.0450
# Epoch 14/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0373 - val_loss: 0.0458
# Saved fine-tuned site-specific weights to state/lstm_site0_finetuned.weights.h5
# Saved site-specific scaler to state/lstm_site0_scaler.npz
# Saved fine-tune loss curve to charts/lstm_site0_finetune_loss.png

# %% [markdown]
# ## Step 3: Run the Agentic Analytics Copilot
#
# This step runs the complete agentic analytics pipeline:
# - Daily KPI analysis
# - Hybrid anomaly detection using STL and LSTM
# - Action recommendation based on a predefined playbook
# - User feedback logging (approve/reject)
#
# The system outputs a daily analytics brief and saves visualizations.

# %%
# Run the agentic analytics copilot
# !printf "y\n" | python main.py
# Out:
# 2025-12-15 19:51:12.450151: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /opt/anaconda3/envs/tf311/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /opt/anaconda3/envs/tf311/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 12 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
#
# Daily Brief — 2025-12-15
# KPI today:
# - sessions: 1304
# - conversion_rate: 0.028
# - revenue: $2310.02
#
# Anomalies (Hybrid z-scores: STL + LSTM):
# - sessions: none (z=-0.72, stl=-1.14, lstm=-0.29)
# - conv_rate: none (z=+0.90, stl=+0.11, lstm=+1.70)
# - revenue:  none (z=-0.27, stl=+0.09, lstm=-0.63)
#
# Suggested next step:
# → No action; monitor another day.
#
# Chart saved: charts/conv_rate.png
# Approve action? (y/n): Logged as approved.
